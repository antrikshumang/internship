# %% [markdown]
# # 1) Write a python program to display all the header tags from wikipedia.org and make data frame.

# %%
from bs4 import BeautifulSoup as bs
import requests as rq

page = rq.get('https://wikipedia.org')
soup = bs(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia</title>
# <meta content="Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation." name="description"/>
# <script>
# document.documentElement.className = document.documentElement.className.replace( /(^|\s)no-js(\s|$)/, "$1js-enabled$2" );
# </script>
# <meta content="initial-scale=1,user-scalable=yes" name="viewport"/>
# <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
# <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
# <link href="//creativecommons.org/licenses/by-sa/4.0/" rel="license"/>
# <style>
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

response = requests.get("https://en.wikipedia.org/wiki/Main_Page")


soup = BeautifulSoup(response.content)

header_tags = soup.find_all(['h1', 'h2', 'h3', 'h4', 'h5', 'h6'])

header_text = []

for i in header_tags:
    header_text.append(i.text)

df = pd.DataFrame({'Headers': header_text})

print(df)
# Out:
#                          Headers
# 0                      Main Page
# 1           Welcome to Wikipedia
# 2  From today's featured article
# 3               Did you know ...
# 4                    In the news
# 5                    On this day
# 6       Today's featured picture
# 7       Other areas of Wikipedia
# 8    Wikipedia's sister projects
# 9            Wikipedia languages

# %% [markdown]
# # 2) Write s python program to display list of respected former presidents of India(i.e. Name , Term ofoffice)
# from https://presidentofindia.nic.in/former-presidents.htm and make data frame.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

response = requests.get("https://presidentofindia.nic.in/former-presidents.htm")

soup = BeautifulSoup(response.content)

name = soup.find_all("h3")
term = soup.find_all("p")

names = []
terms = []

for n in name:
    names.append(n.text)
for t in term:
    terms.append(t.text)

df = pd.DataFrame({'Names': names})

df2 = pd.DataFrame({'Terms':terms})
print(df)
print(df2)
# Out:
#                                           Names
# 0           Shri Ram Nath Kovind (birth - 1945)
# 1             Shri Pranab Mukherjee (1935-2020)
# 2   Smt Pratibha Devisingh Patil (birth - 1934)
# 3            DR. A.P.J. Abdul Kalam (1931-2015)
# 4            Shri K. R. Narayanan (1920 - 2005)
# 5           Dr Shankar Dayal Sharma (1918-1999)
# 6               Shri R Venkataraman (1910-2009)
# 7                  Giani Zail Singh (1916-1994)
# 8         Shri Neelam Sanjiva Reddy (1913-1996)
# 9          Dr. Fakhruddin Ali Ahmed (1905-1977)
# 10     Shri Varahagiri Venkata Giri (1894-1980)
# 11                 Dr. Zakir Husain (1897-1969)
# 12     Dr. Sarvepalli Radhakrishnan (1888-1975)
# 13             Dr. Rajendra Prasad (1884-1963)
#                                                 Terms
# 0     Term of Office: 25 July, 2017 to 25 July, 2022
# 1                        https://ramnathkovind.nic.in
# 2     Term of Office: 25 July, 2012 to 25 July, 2017
# ...

# %% [markdown]
# # 3) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape and make data frame
# a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
# b) Top 10 ODI Batsmen along with the records of their team and rating.
# c) Top 10 ODI bowlers along with the records of their team and rating.

# %%
#partA
import requests
from bs4 import BeautifulSoup
import pandas as pd

response = requests.get("https://www.icc-cricket.com/rankings/mens/team-rankings/odi")

soup = BeautifulSoup(response.content)

team1=soup.find("td",class_="rankings-block__banner--team-name")
match1=soup.find("td",class_="rankings-block__banner--matches")
point1=soup.find("td",class_="rankings-block__banner--points")
rating1=soup.find("td",class_="rankings-block__banner--rating u-text-right")

team= soup.find_all("td",class_="table-body__cell rankings-table__team")
teams=[]
tm1=team1.text
teams.append(tm1)
             


match = soup.find_all("td",class_="table-body__cell u-center-text")
matches = []
m1=match1.text
matches.append(m1)
             

point = soup.find_all("td",class_="table-body__cell u-center-text")
points = []
pp1=point1.text
points.append(pp1)
             
rating = soup.find_all("td",class_="table-body__cell u-text-right rating")
ratings = []

r1=rating1.text
ratings.append(r1)
             

for t in team:
    teams.append(t.text)
for m in match:
    matches.append(m.text)
for p in point:
    points.append(p.text)
for r in rating:
    ratings.append(r.text)

df = pd.DataFrame({'Teams':teams[0:10],'Matches':matches[0:20:2],'Points':points[0:20:2],'Rating':ratings[0:10]})

df1 =pd.DataFrame({'Teams':teams})

df2 = pd.DataFrame({'matches':matches})

df3 = pd.DataFrame({'points':points})
    
df4 = pd.DataFrame({'ratings':ratings})


df
# Out:
#                     Teams Matches Points  \
# 0    \n\nAustralia\nAUS\n      23  2,714
# 1     \n\nPakistan\nPAK\n   2,316  2,316
# 2        \n\nIndia\nIND\n   3,807  3,807
# 3   \n\nNew Zealand\nNZ\n   2,806  2,806
# 4      \n\nEngland\nENG\n   2,426  2,426
# 5  \n\nSouth Africa\nSA\n   1,910  1,910
# 6   \n\nBangladesh\nBAN\n   2,520  2,520
# 7  \n\nAfghanistan\nAFG\n   1,361  1,361
# 8     \n\nSri Lanka\nSL\n   2,794  2,794
# 9   \n\nWest Indies\nWI\n   2,312  2,312
#
#                                               Rating
# 0  \n                            118\n           ...
# 1                                                116
# 2                                                115
# 3                                                104
# 4                                                101
# 5                                                101
# 6                                                 93
# 7                                                 91
# ...

# %%
# part b) Top 10 ODI Batsmen along with the records of their team and rating.
import requests
from bs4 import BeautifulSoup
import pandas as pd

response = requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting")
soup = BeautifulSoup(response.content)

# bs team rating




bat1=soup.find("div",class_="rankings-block__banner--name-large")
batsman = soup.find_all("td",class_="table-body__cell rankings-table__name name")
batsmen = [bat1]




t1=soup.find("div",class_="rankings-block__banner--nationality")
team = soup.find_all("span",class_="table-body__logo-text")
teams = [t1]

r1=soup.find("div",class_="rankings-block__banner--rating")
rating = soup.find_all("td",class_="rating")
ratings = [r1]


for b in batsman:
    batsmen.append(b.text)

for t in team:
    teams.append(t.text)

for r in rating:
    ratings.append(r.text)
    
    
# # for r in rating:
# #     ratings.append(r.text)

df1 = pd.DataFrame({'Batsmen':batsmen[0:10]})
df2 = pd.DataFrame({'Rating':ratings})
df3 = pd.DataFrame({'Teams':teams[0:10]})
df4 = pd.DataFrame({'Rating':ratings[0:10]})



df3 = pd.DataFrame({'Batsmen':batsmen[0:10],'Teams':teams[0:10],'Rating':ratings[0:10]})
df3
# Out:
#                      Batsmen                                        Teams  \
# 0               [Babar Azam]  [\n, [], \n, [], PAK\n                    ]
# 1  \nRassie van der Dussen\n                                           SA
# 2           \nFakhar Zaman\n                                          PAK
# 3            \nImam-ul-Haq\n                                          PAK
# 4           \nShubman Gill\n                                          IND
# 5           \nHarry Tector\n                                          IRE
# 6           \nDavid Warner\n                                          AUS
# 7            \nVirat Kohli\n                                          IND
# 8        \nQuinton de Kock\n                                           SA
# 9           \nRohit Sharma\n                                          IND
#
#   Rating
# 0  [886]
# 1    777
# 2    755
# 3    745
# 4    738
# 5    726
# 6    726
# 7    719
# 8    718
# 9    707

# %%
# part c) Top 10 ODI bowlers along with the records of their team and rating.

import requests
from bs4 import BeautifulSoup
import pandas as pd

response = requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling")
soup = BeautifulSoup(response.content)




b1=soup.find("div",class_="u-flex-center u-text-left")
bowler = soup.find_all("td",class_="table-body__cell rankings-table__name name")
bowlers = []
# b2= b1.text
bowlers.append(b1)

b2=b1.text.split("\n")
for element in b2 :
    if element:
        bowlers.append(element)





t1=soup.find("div",class_="rankings-block__banner--nationality")
team = soup.find_all("span",class_="table-body__logo-text")
teams = []

teams.append(t1)
t2=teams[0].text
teams.append(t2)




r1=soup.find("div",class_="rankings-block__banner--rating")
rating = soup.find_all("td",class_="rating")
ratings = []
ratings.append(r1.text)
rating

for bl in bowler:
    bowlers.append(bl.text)

for t in team:
    teams.append(t.text)

for r in rating:
    ratings.append(r.text)
    
    
# # for r in rating:
# #     ratings.append(r.text)

# # df = pd.DataFrame({'Rating':ratings})
df = pd.DataFrame({'Bowler':bowlers[0:10],'Teams':teams[0:10],'Rating':ratings[0:10]})

df = pd.DataFrame({'Bowler':bowlers[1:11],'Teams':teams[1:11],'Rating':ratings[0:10]})

df
# Out:
#                  Bowler                          Teams Rating
# 0        Josh Hazlewood  \n\nAUS\n                        705
# 1    \nMohammed Siraj\n                            IND    691
# 2    \nMitchell Starc\n                            AUS    686
# 3       \nRashid Khan\n                            AFG    682
# 4        \nMatt Henry\n                             NZ    667
# 5  \nMujeeb Ur Rahman\n                            AFG    661
# 6       \nTrent Boult\n                             NZ    660
# 7        \nAdam Zampa\n                            AUS    652
# 8    \nShaheen Afridi\n                            PAK    630
# 9   \nShakib Al Hasan\n                            BAN    618

# %% [markdown]
# # 4) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape and make data frame
#
# a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.
# b) Top 10 women’s ODI Batting players along with the records of their team and rating.
# c) Top 10 women’s ODI all-rounder along with the records of their team and rating.

# %%
#partA Top 10 ODI teams in women’s cricket along with the records for matches, points and rating
import requests
from bs4 import BeautifulSoup
import pandas as pd

response = requests.get("https://www.icc-cricket.com/rankings/womens/team-rankings/odi")

soup = BeautifulSoup(response.content)

team1=soup.find("td",class_="rankings-block__banner--team-name")
match1=soup.find("td",class_="rankings-block__banner--matches")
point1=soup.find("td",class_="rankings-block__banner--points")
rating1=soup.find("td",class_="rankings-block__banner--rating u-text-right")

team= soup.find_all("td",class_="table-body__cell rankings-table__team")
teams=[]
tm1=team1.text
teams.append(tm1)
             


match = soup.find_all("td",class_="table-body__cell u-center-text")
matches = []
m1=match1.text
matches.append(m1)
             

point = soup.find_all("td",class_="table-body__cell u-center-text")
points = []
pp1=point1.text
points.append(pp1)
             
rating = soup.find_all("td",class_="table-body__cell u-text-right rating")
ratings = []

r1=rating1.text
ratings.append(r1)
             

for t in team:
    teams.append(t.text)
for m in match:
    matches.append(m.text)
for p in point:
    points.append(p.text)
for r in rating:
    ratings.append(r.text)

df = pd.DataFrame({'Teams':teams[0:10],'Matches':matches[0:20:2],'Points':points[0:20:2],'Rating':ratings[0:10]})

df1 =pd.DataFrame({'Teams':teams})

df2 = pd.DataFrame({'matches':matches})

df3 = pd.DataFrame({'points':points})
    
df4 = pd.DataFrame({'ratings':ratings})


df
# Out:
#                     Teams Matches Points  \
# 0    \n\nAustralia\nAUS\n      21  3,603
# 1      \n\nEngland\nENG\n   3,342  3,342
# 2  \n\nSouth Africa\nSA\n   3,098  3,098
# 3        \n\nIndia\nIND\n   2,820  2,820
# 4   \n\nNew Zealand\nNZ\n   2,688  2,688
# 5   \n\nWest Indies\nWI\n   2,743  2,743
# 6   \n\nBangladesh\nBAN\n     977    977
# 7     \n\nSri Lanka\nSL\n     820    820
# 8     \n\nThailand\nTHA\n     806    806
# 9     \n\nPakistan\nPAK\n   1,678  1,678
#
#                                               Rating
# 0  \n                            172\n           ...
# 1                                                119
# 2                                                119
# 3                                                104
# 4                                                 96
# 5                                                 95
# 6                                                 70
# 7                                                 68
# ...

# %%
# part b)Top 10 women’s ODI Batting players along with the records of their team and rating.
import requests
from bs4 import BeautifulSoup
import pandas as pd

response = requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting")
soup = BeautifulSoup(response.content)

# bs team rating




bat1=soup.find("div",class_="rankings-block__banner--name-large")
batsman = soup.find_all("td",class_="table-body__cell rankings-table__name name")
batsmen = [bat1]




t1=soup.find("div",class_="rankings-block__banner--nationality")
team = soup.find_all("span",class_="table-body__logo-text")
teams = [t1]

r1=soup.find("div",class_="rankings-block__banner--rating")
rating = soup.find_all("td",class_="rating")
ratings = [r1]


for b in batsman:
    batsmen.append(b.text)

for t in team:
    teams.append(t.text)

for r in rating:
    ratings.append(r.text)
    
    
# # for r in rating:
# #     ratings.append(r.text)

df1 = pd.DataFrame({'Batsmen':batsmen[0:10]})
df2 = pd.DataFrame({'Rating':ratings})
df3 = pd.DataFrame({'Teams':teams[0:10]})
df4 = pd.DataFrame({'Rating':ratings[0:10]})



df3 = pd.DataFrame({'Batsmen':batsmen[0:10],'Teams':teams[0:10],'Rating':ratings[0:10]})
df3
# Out:
#                  Batsmen                                       Teams Rating
# 0  [Chamari Athapaththu]  [\n, [], \n, [], SL\n                    ]  [758]
# 1        \nBeth Mooney\n                                         AUS    754
# 2    \nLaura Wolvaardt\n                                          SA    732
# 3     \nNatalie Sciver\n                                         ENG    731
# 4        \nMeg Lanning\n                                         AUS    717
# 5   \nHarmanpreet Kaur\n                                         IND    716
# 6    \nSmriti Mandhana\n                                         IND    714
# 7       \nEllyse Perry\n                                         AUS    626
# 8    \nStafanie Taylor\n                                          WI    618
# 9     \nTammy Beaumont\n                                         ENG    595

# %%
#partc) Top 10 women’s ODI all-rounder along with the records of their team and rating.

import requests
from bs4 import BeautifulSoup
import pandas as pd

response = requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder")
soup = BeautifulSoup(response.content)




b1=soup.find("div",class_="u-flex-center u-text-left")
bowler = soup.find_all("td",class_="table-body__cell rankings-table__name name")
bowlers = []
# b2= b1.text
bowlers.append(b1)

b2=b1.text.split("\n")
for element in b2 :
    if element:
        bowlers.append(element)





t1=soup.find("div",class_="rankings-block__banner--nationality")
team = soup.find_all("span",class_="table-body__logo-text")
teams = []

teams.append(t1)
t2=teams[0].text
teams.append(t2)




r1=soup.find("div",class_="rankings-block__banner--rating")
rating = soup.find_all("td",class_="rating")
ratings = []
ratings.append(r1.text)
rating

for bl in bowler:
    bowlers.append(bl.text)

for t in team:
    teams.append(t.text)

for r in rating:
    ratings.append(r.text)
    
    
# # for r in rating:
# #     ratings.append(r.text)

# # df = pd.DataFrame({'Rating':ratings})
df = pd.DataFrame({'Bowler':bowlers[0:10],'Teams':teams[0:10],'Rating':ratings[0:10]})

df = pd.DataFrame({'Bowler':bowlers[1:11],'Teams':teams[1:11],'Rating':ratings[0:10]})

df
# Out:
#                  Bowler                         Teams Rating
# 0       Hayley Matthews  \n\nWI\n                        382
# 1    \nNatalie Sciver\n                           ENG    371
# 2      \nEllyse Perry\n                           AUS    366
# 3    \nMarizanne Kapp\n                            SA    349
# 4       \nAmelia Kerr\n                            NZ    328
# 5     \nDeepti Sharma\n                           IND    322
# 6  \nAshleigh Gardner\n                           AUS    292
# 7     \nJess Jonassen\n                           AUS    250
# 8     \nSophie Devine\n                            NZ    233
# 9          \nNida Dar\n                           PAK    232

# %% [markdown]
# # 5) Write a python program to scrape mentioned news details from https://www.cnbc.com/world/?region=world and
# make data framei) Headline
# ii) Time
# iii) News Link

# %%
#https://www.cnbc.com/world/?region=world


import requests
from bs4 import BeautifulSoup
import pandas as pd

response = requests.get("https://www.cnbc.com/world/?region=world")
soup = BeautifulSoup(response.content,"html.parser")

headline=soup.find_all("a",class_="LatestNews-headline")
headlines=[]

for h in headline:
    headlines.append(h.text)

new=soup.find_all("time",class_="LatestNews-timestamp")
news=[]

for n in new:
    news.append(n.text)

    
df2= pd.DataFrame({"new":news})

links = []
for anchor_tag in soup.find_all("a", class_="LatestNews-headline"):
    link = anchor_tag["href"]
    links.append(link)
df= pd.DataFrame({"Headlines":headlines[0:20],"Time":news[0:20],"Links":links[0:20]})
df
# Out:
#                                             Headlines         Time  \
# 0   Record heat meets record wildfires in Canada, ...   16 Min Ago
# 1   Actors union will go on strike, shutting down ...   18 Min Ago
# 2   House Democrats, Republicans clash over proxy ...   19 Min Ago
# 3   Analysts are getting bullish on these stocks s...   32 Min Ago
# 4   Elon Musk's Twitter files data-scraping lawsui...   32 Min Ago
# 5   Canadian ports strike is over, but supply chai...   48 Min Ago
# 6   What investors need to know about the crossove...   55 Min Ago
# 7   HHS to provide free Covid vaccines to uninsure...   58 Min Ago
# 8   Beware of these possible blowups this earnings...   1 Hour Ago
# 9   Trump to host screening of divisive anti-child...   1 Hour Ago
# 10  What cooling inflation means for your Series I...   1 Hour Ago
# 11  St. Louis Fed President Bullard says he's step...   1 Hour Ago
# 12  Here's the new default font for Microsoft Outl...  2 Hours Ago
# ...

# %% [markdown]
# # 6) Write a python program to scrape the details of most downloaded articles from AI in last 90days.
# www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles
# Scrape below mentioned details and make data frame
# i) Paper Title
# ii) Authors
# iii) Published Date
# iv) Paper URL

# %%
# Paper_Title               Authors                    Published_Date                       Paper_url



import requests 
from bs4 import BeautifulSoup as bs
import pandas as pd

page='https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles/'

response = requests.get(page)
soup=bs(response.content,"html.parser")



ppr=soup.find_all("h2",class_="sc-1qrq3sd-1 gRGSUS sc-1nmom32-0 sc-1nmom32-1 btcbYu goSKRg")
pprs=[]

for pp in ppr:
    pprs.append(pp.text)

athr=soup.find_all("span",class_="sc-1w3fpd7-0 dnCnAO")
athrs=[]

for a in athr:
    athrs.append(a.text)

df2 = pd.DataFrame({"Authors":athrs})
   
        

    
#     temp
    
# =soup.find_all("",class_="")
# =[]

# for p in :
#     .append(.text)
# df1=pd.DataFrame({"":})
    

    
#    working 
    

    
    

pd1=soup.find_all("span",class_="sc-1thf9ly-2 dvggWt")
pds=[]

for p in pd1:
    pds.append(p.text)
# df3 = pd.DataFrame({'Published_Date':pds})
       
    
    
    
    
    
    


# =soup.find_all("",class_="")
# =[]

# for p in :
#     .append(.text)
# df1=pd.DataFrame({"":})
       
    

links = []
for a_tag in soup.find_all("a", class_="sc-5smygv-0 fIXTHm"):
    link = a_tag["href"]
    links.append(link)
    
    
    
    
    
df= pd.DataFrame({"Titles":pprs,"Authors":athrs,'Published_Date':pds,"Link":links})


df
# Out:
#                                                Titles  \
# 0                                    Reward is enough
# 1   Explanation in artificial intelligence: Insigh...
# 2              Creativity and artificial intelligence
# 3   Conflict-based search for optimal multi-agent ...
# 4   Knowledge graphs as tools for explainable mach...
# 5   Law and logic: A review from an argumentation ...
# 6   Between MDPs and semi-MDPs: A framework for te...
# 7   Explaining individual predictions when feature...
# 8       Multiple object tracking: A literature review
# 9   A survey of inverse reinforcement learning: Ch...
# 10  Evaluating XAI: A comparison of rule-based and...
# 11  Explainable AI tools for legal reasoning about...
# 12            Hard choices in artificial intelligence
# 13  Assessing the communication gap between AI mod...
# 14  Explaining black-box classifiers using post-ho...
# 15  The Hanabi challenge: A new frontier for AI re...
# ...
